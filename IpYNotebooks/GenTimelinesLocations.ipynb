# %%
ls
# Out:
# All_locations_experiment.ipynb     De_Bruijn_VIS_orig.ipynb           KaggleExploration.ipynb            kaggle_expl2_test10_csv.ipynb
# All_locations_perhour_stats.ipynb  GenTimelinesKeywords.ipynb         LocationsAPITest.ipynb             kaggle_expl2_test9_csv.ipynb
# DataMining/                        GenTimelinesLocations.ipynb        d3_custom_graph.ipynb              temp.json_1
# De_Bruijn_VIS.ipynb                IpyClustering.ipynb                ipcluster.ipynb

# %%
len(json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-09140122a4fe> in <module>()
# ----> 1 len(json)
#
# NameError: name 'json' is not defined

# %%
ls
# Out:
# All_locations_experiment.ipynb     De_Bruijn_VIS_orig.ipynb           KaggleExploration.ipynb            kaggle_expl2_test10_csv.ipynb
# All_locations_perhour_stats.ipynb  GenTimelinesKeywords.ipynb         LocationsAPITest.ipynb             kaggle_expl2_test9_csv.ipynb
# DataMining/                        GenTimelinesLocations.ipynb        d3_custom_graph.ipynb              temp.json_1
# De_Bruijn_VIS.ipynb                IpyClustering.ipynb                ipcluster.ipynb

# %%
f = open('./DataMining/uncompressed/all_locations/all_locs_reduced.json1')

# %%
from json import loads 
json  = loads(f.read())

# %%
json.keys()
# Out:
# [u'2012-11-10T12:00:00',
#  u'2012-11-09T19:00:00',
#  u'2012-11-02T16:00:00',
#  u'2012-11-06T19:00:00',
#  u'2012-11-05T15:00:00',
#  u'2012-11-04T19:00:00',
#  u'2012-11-03T16:00:00',
#  u'2012-11-11T11:00:00',
#  u'2012-11-14T03:00:00',
#  u'2012-11-12T13:00:00',
#  u'2012-11-02T07:00:00',
#  u'2012-11-09T13:00:00',
#  u'2012-11-05T12:00:00',
#  u'2012-11-11T12:00:00',
#  u'2012-11-14T02:00:00',
#  u'2012-11-01T09:00:00',
#  u'2012-11-15T08:00:00',
#  u'2012-11-07T19:00:00',
#  u'2012-11-09T01:00:00',
#  u'2012-11-02T05:00:00',
#  u'2012-11-06T16:00:00',
#  u'2012-11-04T12:00:00',
#  u'2012-11-07T21:00:00',
#  u'2012-11-13T18:00:00',
#  u'2012-11-01T22:00:00',
#  u'2012-11-03T23:00:00',
#  u'2012-11-11T02:00:00',
#  u'2012-11-02T04:00:00',
#  u'2012-11-09T22:00:00',
#  u'2012-11-11T20:00:00',
#  u'2012-11-06T23:00:00',
#  u'2012-11-04T15:00:00',
#  u'2012-11-13T12:00:00',
#  u'2012-11-11T01:00:00',
#  u'2012-11-14T04:00:00',
#  u'2012-11-06T18:00:00',
#  u'2012-11-13T21:00:00',
#  u'2012-11-12T18:00:00',
#  u'2012-11-06T05:00:00',
#  u'2012-11-04T05:00:00',
#  u'2012-11-14T18:00:00',
#  u'2012-11-02T15:00:00',
#  u'2012-11-06T17:00:00',
#  u'2012-11-11T14:00:00',
#  u'2012-11-11T21:00:00',
#  u'2012-11-15T09:00:00',
#  u'2012-11-03T04:00:00',
#  u'2012-11-04T02:00:00',
#  u'2012-11-01T12:00:00',
#  u'2012-11-03T18:00:00',
#  u'2012-11-15T22:00:00',
#  u'2012-11-02T03:00:00',
#  u'2012-11-13T14:00:00',
#  u'2012-11-11T16:00:00',
#  u'2012-11-06T20:00:00',
#  u'2012-11-14T13:00:00',
#  u'2012-11-01T04:00:00',
#  u'2012-11-02T18:00:00',
#  u'2012-11-11T17:00:00',
#  u'2012-11-09T04:00:00',
#  u'2012-11-06T04:00:00',
#  u'2012-11-11T07:00:00',
#  u'2012-11-03T17:00:00',
#  u'2012-11-01T19:00:00',
#  u'2012-11-11T05:00:00',
#  u'2012-11-15T16:00:00',
#  u'2012-11-11T04:00:00',
#  u'2012-11-15T23:00:00',
#  u'2012-11-03T22:00:00',
#  u'2012-11-13T00:00:00',
#  u'2012-11-11T10:00:00',
#  u'2012-11-06T21:00:00',
#  u'2012-11-15T05:00:00',
#  u'2012-11-02T17:00:00',
#  u'2012-11-06T10:00:00',
#  u'2012-11-15T17:00:00',
#  u'2012-11-07T09:00:00',
#  u'2012-11-11T03:00:00',
#  u'2012-11-01T10:00:00',
#  u'2012-11-08T13:00:00',
#  u'2012-11-09T10:00:00',
#  u'2012-11-15T20:00:00',
#  u'2012-11-13T23:00:00',
#  u'2012-11-10T05:00:00',
#  u'2012-11-11T18:00:00',
#  u'2012-11-05T04:00:00',
#  u'2012-11-06T03:00:00',
#  u'2012-11-08T01:00:00',
#  u'2012-11-15T04:00:00',
#  u'2012-11-16T05:00:00',
#  u'2012-11-12T17:00:00',
#  u'2012-11-14T11:00:00',
#  u'2012-11-12T01:00:00',
#  u'2012-11-03T00:00:00',
#  u'2012-11-13T16:00:00',
#  u'2012-11-09T15:00:00',
#  u'2012-11-10T16:00:00',
#  u'2012-11-05T01:00:00',
#  u'2012-11-05T13:00:00',
#  u'2012-11-13T11:00:00',
#  u'2012-11-06T13:00:00',
#  u'2012-11-06T14:00:00',
#  u'2012-11-14T19:00:00',
#  u'2012-11-15T21:00:00',
#  u'2012-11-03T13:00:00',
#  u'2012-11-14T21:00:00',
#  u'2012-11-12T22:00:00',
#  u'2012-11-10T23:00:00',
#  u'2012-11-05T16:00:00',
#  u'2012-11-04T14:00:00',
#  u'2012-11-15T10:00:00',
#  u'2012-11-03T19:00:00',
#  u'2012-11-12T00:00:00',
#  u'2012-11-06T00:00:00',
#  u'2012-11-06T07:00:00',
#  u'2012-11-03T07:00:00',
#  u'2012-11-02T22:00:00',
#  u'2012-11-14T12:00:00',
#  u'2012-11-04T11:00:00',
#  u'2012-11-04T03:00:00',
#  u'2012-11-15T03:00:00',
#  u'2012-11-08T02:00:00',
#  u'2012-11-10T04:00:00',
#  u'2012-11-12T12:00:00',
#  u'2012-11-09T00:00:00',
#  u'2012-11-10T18:00:00',
#  u'2012-11-05T07:00:00',
#  u'2012-11-03T14:00:00',
#  u'2012-11-12T03:00:00',
#  u'2012-11-12T04:00:00',
#  u'2012-11-04T06:00:00',
#  u'2012-11-10T17:00:00',
#  u'2012-11-12T19:00:00',
#  u'2012-11-09T23:00:00',
#  u'2012-11-14T07:00:00',
#  u'2012-11-08T22:00:00',
#  u'2012-11-15T13:00:00',
#  u'2012-11-15T14:00:00',
#  u'2012-11-05T08:00:00',
#  u'2012-11-05T10:00:00',
#  u'2012-11-02T08:00:00',
#  u'2012-11-03T21:00:00',
#  u'2012-11-03T02:00:00',
#  u'2012-11-09T14:00:00',
#  u'2012-11-06T12:00:00',
#  u'2012-11-07T08:00:00',
#  u'2012-11-10T22:00:00',
#  u'2012-11-08T17:00:00',
#  u'2012-11-15T00:00:00',
#  u'2012-11-15T07:00:00',
#  u'2012-11-02T10:00:00',
#  u'2012-11-04T17:00:00',
#  u'2012-11-12T02:00:00',
#  u'2012-11-11T22:00:00',
#  u'2012-11-03T11:00:00',
#  u'2012-11-16T00:00:00',
#  u'2012-11-06T01:00:00',
#  u'2012-11-14T09:00:00',
#  u'2012-11-09T05:00:00',
#  u'2012-11-08T08:00:00',
#  u'2012-11-01T21:00:00',
#  u'2012-11-04T18:00:00',
#  u'2012-11-04T00:00:00',
#  u'2012-11-12T10:00:00',
#  u'2012-11-03T09:00:00',
#  u'2012-11-13T03:00:00',
#  u'2012-11-14T10:00:00',
#  u'2012-11-01T14:00:00',
#  u'2012-11-16T04:00:00',
#  u'2012-11-07T20:00:00',
#  u'2012-11-11T08:00:00',
#  u'2012-11-09T21:00:00',
#  u'2012-11-10T00:00:00',
#  u'2012-11-13T20:00:00',
#  u'2012-11-13T10:00:00',
#  u'2012-11-13T02:00:00',
#  u'2012-11-01T08:00:00',
#  u'2012-11-07T01:00:00',
#  u'2012-11-09T11:00:00',
#  u'2012-11-01T07:00:00',
#  u'2012-11-10T13:00:00',
#  u'2012-11-13T15:00:00',
#  u'2012-11-15T01:00:00',
#  u'2012-11-10T19:00:00',
#  u'2012-11-07T12:00:00',
#  u'2012-11-08T19:00:00',
#  u'2012-11-09T07:00:00',
#  u'2012-11-10T07:00:00',
#  u'2012-11-07T07:00:00',
#  u'2012-11-05T20:00:00',
#  u'2012-11-14T05:00:00',
#  u'2012-11-01T15:00:00',
#  u'2012-11-14T14:00:00',
#  u'2012-11-08T06:00:00',
#  u'2012-11-09T18:00:00',
#  u'2012-11-10T14:00:00',
#  u'2012-11-07T14:00:00',
#  u'2012-11-13T05:00:00',
#  u'2012-11-08T18:00:00',
#  u'2012-11-03T06:00:00',
#  u'2012-11-12T09:00:00',
#  u'2012-11-14T17:00:00',
#  u'2012-11-13T13:00:00',
#  u'2012-11-10T21:00:00',
#  u'2012-11-10T02:00:00',
#  u'2012-11-08T07:00:00',
#  u'2012-11-05T03:00:00',
#  u'2012-11-03T15:00:00',
#  u'2012-11-09T08:00:00',
#  u'2012-11-14T06:00:00',
#  u'2012-11-05T19:00:00',
#  u'2012-11-05T18:00:00',
#  u'2012-11-06T11:00:00',
#  u'2012-11-04T23:00:00',
#  u'2012-11-08T21:00:00',
#  u'2012-11-15T19:00:00',
#  u'2012-11-10T11:00:00',
#  u'2012-11-01T20:00:00',
#  u'2012-11-05T14:00:00',
#  u'2012-11-03T20:00:00',
#  u'2012-11-13T06:00:00',
#  u'2012-11-13T01:00:00',
#  u'2012-11-09T17:00:00',
#  u'2012-11-12T21:00:00',
#  u'2012-11-06T02:00:00',
#  u'2012-11-10T09:00:00',
#  u'2012-11-09T09:00:00',
#  u'2012-11-08T14:00:00',
#  u'2012-11-08T04:00:00',
#  u'2012-11-02T19:00:00',
#  u'2012-11-08T03:00:00',
#  u'2012-11-12T14:00:00',
#  u'2012-11-08T20:00:00',
#  u'2012-11-05T23:00:00',
#  u'2012-11-04T13:00:00',
#  u'2012-11-03T03:00:00',
#  u'2012-11-14T20:00:00',
#  u'2012-11-01T11:00:00',
#  u'2012-11-04T09:00:00',
#  u'2012-11-09T16:00:00',
#  u'2012-11-01T06:00:00',
#  u'2012-11-08T15:00:00',
#  u'2012-11-12T08:00:00',
#  u'2012-11-04T04:00:00',
#  u'2012-11-14T01:00:00',
#  u'2012-11-03T08:00:00',
#  u'2012-11-03T10:00:00',
#  u'2012-11-12T07:00:00',
#  u'2012-11-02T23:00:00',
#  u'2012-11-08T05:00:00',
#  u'2012-11-15T11:00:00',
#  u'2012-11-16T01:00:00',
#  u'2012-11-07T05:00:00',
#  u'2012-11-02T02:00:00',
#  u'2012-11-07T23:00:00',
#  u'2012-11-01T23:00:00',
#  u'2012-11-02T06:00:00',
#  u'2012-11-07T06:00:00',
#  u'2012-11-01T16:00:00',
#  u'2012-11-15T02:00:00',
#  u'2012-11-15T12:00:00',
#  u'2012-11-02T13:00:00',
#  u'2012-11-05T22:00:00',
#  u'2012-11-11T19:00:00',
#  u'2012-11-09T03:00:00',
#  u'2012-11-07T16:00:00',
#  u'2012-11-13T07:00:00',
#  u'2012-11-04T20:00:00',
#  u'2012-11-07T22:00:00',
#  u'2012-11-12T15:00:00',
#  u'2012-11-07T15:00:00',
#  u'2012-11-13T08:00:00',
#  u'2012-11-03T01:00:00',
#  u'2012-11-02T00:00:00',
#  u'2012-11-08T12:00:00',
#  u'2012-11-07T00:00:00',
#  u'2012-11-01T05:00:00',
#  u'2012-11-11T15:00:00',
#  u'2012-11-10T06:00:00',
#  u'2012-11-06T15:00:00',
#  u'2012-11-14T08:00:00',
#  u'2012-11-11T23:00:00',
#  u'2012-11-02T01:00:00',
#  u'2012-11-03T12:00:00',
#  u'2012-11-07T02:00:00',
#  u'2012-11-07T03:00:00',
#  u'2012-11-01T13:00:00',
#  u'2012-11-07T13:00:00',
#  u'2012-11-16T03:00:00',
#  u'2012-11-02T09:00:00',
#  u'2012-11-11T06:00:00',
#  u'2012-11-10T15:00:00',
#  u'2012-11-06T06:00:00',
#  u'2012-11-05T06:00:00',
#  u'2012-11-08T23:00:00',
#  u'2012-11-13T22:00:00',
#  u'2012-11-11T13:00:00',
#  u'2012-11-07T11:00:00',
#  u'2012-11-04T21:00:00',
#  u'2012-11-07T10:00:00',
#  u'2012-11-12T20:00:00',
#  u'2012-11-13T17:00:00',
#  u'2012-11-09T02:00:00',
#  u'2012-11-10T20:00:00',
#  u'2012-11-05T11:00:00',
#  u'2012-11-08T11:00:00',
#  u'2012-11-05T21:00:00',
#  u'2012-11-08T16:00:00',
#  u'2012-11-09T12:00:00',
#  u'2012-11-07T04:00:00',
#  u'2012-11-05T00:00:00',
#  u'2012-11-11T00:00:00',
#  u'2012-11-01T18:00:00',
#  u'2012-11-07T18:00:00',
#  u'2012-11-10T03:00:00',
#  u'2012-11-15T15:00:00',
#  u'2012-11-04T16:00:00',
#  u'2012-11-08T09:00:00',
#  u'2012-11-07T17:00:00',
#  u'2012-11-05T17:00:00',
#  u'2012-11-12T11:00:00',
#  u'2012-11-12T06:00:00',
#  u'2012-11-11T09:00:00',
#  u'2012-11-10T08:00:00',
#  u'2012-11-10T10:00:00',
#  u'2012-11-15T06:00:00',
#  u'2012-11-04T01:00:00',
#  u'2012-11-04T10:00:00',
#  u'2012-11-09T20:00:00',
#  u'2012-11-02T14:00:00',
#  u'2012-11-02T11:00:00',
#  u'2012-11-14T23:00:00',
#  u'2012-11-12T23:00:00',
#  u'2012-11-02T12:00:00',
#  u'2012-11-04T22:00:00',
#  u'2012-11-06T08:00:00',
#  u'2012-11-12T16:00:00',
#  u'2012-11-04T07:00:00',
#  u'2012-11-05T09:00:00',
#  u'2012-11-15T18:00:00',
#  u'2012-11-14T16:00:00',
#  u'2012-11-13T09:00:00',
#  u'2012-11-08T10:00:00',
#  u'2012-11-02T20:00:00',
#  u'2012-11-13T19:00:00',
#  u'2012-11-14T22:00:00',
#  u'2012-11-14T15:00:00',
#  u'2012-11-10T01:00:00',
#  u'2012-11-13T04:00:00',
#  u'2012-11-09T06:00:00',
#  u'2012-11-05T02:00:00',
#  u'2012-11-16T02:00:00',
#  u'2012-11-03T05:00:00',
#  u'2012-11-14T00:00:00',
#  u'2012-11-02T21:00:00',
#  u'2012-11-12T05:00:00',
#  u'2012-11-06T09:00:00',
#  u'2012-11-05T05:00:00',
#  u'2012-11-01T17:00:00',
#  u'2012-11-04T08:00:00',
#  u'2012-11-08T00:00:00',
#  u'2012-11-06T22:00:00']

# %%
len(json[json.keys()[0]])
# Out:
# 1469

# %%
'''
Created on Dec 4, 2012

@author: gparuthi
'''
from json import loads
import dateutil
from StdSuites.Type_Names_Suite import rotation
from IPython import embed
import os

dir = '/Users/gaurav/Documents/Work/Projects/DataMining/uncompressed/locations_cities'
dir2 = '../../uncompressed/locations_11_07_12'

def getCitiesHist(fpath):
    f = open(fpath)
    cities = loads(f.read())
    for c in cities:
        for t in cities[c]:
            count = 0
            for w in cities[c][t]:
                count += cities[c][t][w]
            cities[c][t] = count
    return cities
    
def genMulCities(fpath):
    print 'Generating histogram for timeline' + fpath
    with open(fpath, 'r') as content_file:
        content = content_file.read()
    print len(content)
    json = loads(content)
    for c in json:
        getCity(c,json[c])

def genOneCity(c,fpath):
    with open(fpath, 'r') as content_file:
        content = content_file.read()
    json = loads(content)
    getCity(c,json)
    
def getCity(c,city_json):
    ts = {}
    for k in city_json:
        ts[dateutil.parser.parse(k)] = city_json[k]
    genHist(ts, c)

def getDelhiHist(fpath):
    print 'Generating histogram for timeline' + fpath
    with open(fpath, 'r') as content_file:
        content = content_file.read()
    print len(content)
    json = loads(content)
    
    ts = {}
    for k in json:
        ts[dateutil.parser.parse(k)] = len(json[k])
    return genHist(ts, 'name')
    
def genHist(json, name):
    # generate histogram on this dictionary
    # print json
    data = json.items()
    
    data.sort()
    
    x = [matplotlib.dates.date2num(date) for (date, value) in data]
    y = [value for (date, value) in data]
    
    fig = figure(figsize=(len(x)/3,6))
    
    fig.canvas.set_window_title(name)
    
    graph = fig.add_subplot(111)
    
    # Plot the data as a red line with round markers
    graph.plot(x,y,'r-o')
    
    # Set the xtick locations to correspond to just the dates you entered.
    graph.set_xticks(x)
    
    # Set the xtick labels to correspond to just the dates you entered.
    graph.set_xticklabels(
            [date.strftime("%Y-%m-%d-%I") for (date, value) in data],
            rotation=90, size='small'
            )
    print 'done processing. Now showing...' 
    
    return graph
    #show()
    
    #plot_date(dates, ts.values())
    #show()

if __name__ == '__main__':
    #genMulCities(dir+'/5cities.timeline.json')
    #getDelhiHist('../../../temp.json_1')
    #genOneCity('nyc',os.path.join(dir,'del_11_1_to_11_15.new_timeline'))
    print ''

# %%
locs = json

# %%
len(locs)
# Out:
# 362

# %%
def gen_time_line_for_loc(loc, locs):
    loc_dict = {}
    for k in locs:
        if loc in locs[k]:
            loc_dict[k] = locs[k][loc]
        else:
            loc_dict[k] = 0
            
    # now generate the histogram
    return getCity(loc, loc_dict)

# %%
graph = gen_time_line_for_loc('washington dc',locs)
# Out:
# done processing. Now showing...

# %%
def gen_multiple_timelines_to_graph(loc_list, locs):
    dicts = {}
    for input_loc in loc_list:
        print 'procesing data for: '+input_loc
        loc_dict = {}
        for k in locs:
            date = dateutil.parser.parse(k)
            if date.day > 5:
                loc_dict[date] = 0
                for loc in locs[k]:
                    if input_loc in loc:
                        loc_dict[date] += locs[k][loc]
        dicts[input_loc] = loc_dict
        
    # now generate the histogram
    return genHistMultiple(dicts)

def calc_diff_from_means(json):
    sum =0
    for date in json:
        sum += json[date]
    avg = sum/len(json)
    ret = {}
    for date in json:
        ret[date] = float(json[date]-avg)/float(avg)*100
    return ret

def plot_data(data,loc, graph):
    data.sort()        
    x = [matplotlib.dates.date2num(date) for (date, value) in data]
    y = [value for (date, value) in data]
    # Plot the data as a red line with round markers
    graph.plot(x,y,'-o', label= loc)
    # Set the xtick locations to correspond to just the dates you entered.
    graph.set_xticks(x)
    
    # Set the xtick labels to correspond to just the dates you entered.
    graph.set_xticklabels(
            [date.strftime("%Y-%m-%d-%I") for (date, value) in data],
            rotation=90, size='small'
            )
    graph.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=2, borderaxespad=0.)
    graph.set_xlabel('Time')
    graph.set_ylabel('Number of tweets')

def genHistMultiple(json):
    
    fig = figure(figsize=(len(json[json.keys()[0]])/3,20))
    fig.canvas.set_window_title('multiple cities')
    graph = fig.add_subplot(311)
    graph_means = fig.add_subplot(313)
    for loc in json:
        # generate histogram on this dictionary
        print 'procesing: '+loc
        data = json[loc].items()
        plot_data(data,loc,graph)
        data = calc_diff_from_means(json[loc]).items()
        plot_data(data,loc,graph_means)
        print 'done processing '+loc+'. Now showing...' 
    
    return graph

# %%
gen_multiple_timelines_to_graph(['new york','washington dc', 'los angeles', 'london', 'jakarta', 'tokyo'],locs)
# Out:
# procesing data for: new york
# procesing data for: washington dc
# procesing data for: los angeles
# procesing data for: london
# procesing data for: jakarta
# procesing data for: tokyo
# procesing: tokyo
# done processing tokyo. Now showing...
# procesing: jakarta
# done processing jakarta. Now showing...
# procesing: new york
# done processing new york. Now showing...
# procesing: london
# done processing london. Now showing...
# procesing: los angeles
# done processing los angeles. Now showing...
# procesing: washington dc
# done processing washington dc. Now showing...

# %%
subplot = gen_multiple_timelines_to_graph(['new york','jakarta', 'washington dc'],locs)
# Out:
# procesing data for: new york
# procesing data for: jakarta
# procesing data for: washington dc
# procesing: washington dc
# done processing washington dc. Now showing...
# procesing: jakarta
# done processing jakarta. Now showing...
# procesing: new york
# done processing new york. Now showing...

# %%
#len(locs)
gen_multiple_timelines_to_graph(['new york','washington dc', 'los angeles', 'nairobi', 'dallas', 'beijing', 'houston', 'taiwan', 'delhi'],locs)

# %%
t= datetime.datetime.now()
t.hour
# Out:
# 23

# %%
data = get_city_timelines(['new york'],locs)
#data['new york'].keys()
#data['new york'][dateutil.parser.parse('2012-11-7 04:0:0')]

gen_hist_city_dicts(data)
# Out:
# procesing data for: new york
# procesing: new york

# %%
def getStd(city_dict):
    avg = numpy.std([city_dict[t] for t in city_dict])
    std = numpy.std([city_dict[t] for t in city_dict])
    return std

def get_per_change(city_dict):
    main_hr_count = city_dict[dateutil.parser.parse('2012-11-7 4:0:0')]
    hrsd = []
    for t in city_dict:
        if t.hour == 4 and t != dateutil.parser.parse('2012-11-7 4:0:0'):
            hrsd.append(city_dict[t])
            
    avg = numpy.average(hrsd)
    std = numpy.std(hrsd)
    per_change = (main_hr_count-avg)/avg*100
    return per_change,std

def gen_hist_city_dicts(city_dicts):
    fig = figure()
    fig.canvas.set_window_title('% increase in an hour')
    graph = fig.add_subplot(111)
    final_dict = {}
    for loc in city_dicts:
        print 'procesing: '+loc
        per_change,std = get_per_change(city_dicts[loc])
        final_dict[loc] = {'time':'2012-11-07-04', 'per_change': per_change, 'std':std}
    plot_data_cities_comp(final_dict,graph)
    
"""This method will generate the histogram for input data. i.e. : a json like {city:{time:'', per_change:'', 'std':''}}
"""
def plot_data_cities_comp(data,ax):
    x = data.keys()
    y = [data[loc]['per_change'] for loc in data]
    #Stds= [data[loc]['std'] for loc in data]
    
    ind = numpy.arange(len(x))  # the x locations for the groups
    width = 0.35       # the width of the bars
    
    rects1 = ax.bar(ind, y, width, color='b')
    ax.set_ylabel('% change')
    ax.set_title('% change in tweets for the given hour')
    ax.set_xticks(ind+width)
    ax.set_xticklabels( x )
    
    ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=2, borderaxespad=0.)   

def get_city_timelines(loc_list, locs):
    dicts = {}
    for input_loc in loc_list:
        print 'procesing data for: '+input_loc
        loc_dict = {}
        for k in locs:
            date = dateutil.parser.parse(k)
            loc_dict[date] = 0
            for loc in locs[k]:
                if input_loc in loc:
                    loc_dict[date] += locs[k][loc]
        dicts[input_loc] = loc_dict
    
    return dicts

# %%
locs[locs.keys()[0]].keys()
# Out:
# [u'tasikmalaya',
#  u'milan italy',
#  u'\u3088\u3053\u306f\u307e',
#  u'nottingham',
#  u'banyuwangi',
#  u'durban south africa',
#  u'\u897f\u65e5\u672c',
#  u'paris',
#  u'panam\xe1',
#  u'ontario canada',
#  u'seoul korea',
#  u'\uc9c0\uad6c',
#  u'depok indonesia',
#  u'alexandria egypt',
#  u'las palmas de gran canaria',
#  u'chennai',
#  u'northern ireland',
#  u'georgia',
#  u'manado',
#  u'pilipinas',
#  u'\u5343\u8449\u770c\u677e\u6238\u5e02',
#  u'\u6a2a\u6d5c\u5e02',
#  u'murcia',
#  u'medan ',
#  u'venus',
#  u'\ud55c\uad6d',
#  u'somewhere on earth',
#  u'jamaica',
#  u'in my own world',
#  u'rouen',
#  u'\u65e5\u672c\u306e\u3069\u3053\u304b',
#  u'berlin germany',
#  u'ipoh',
#  u'in my world',
#  u'\u5e03\u56e3',
#  u'panama',
#  u'japan ',
#  u'asia',
#  u'\u5e7b\u60f3\u90f7',
#  u'\u8328\u57ce',
#  u'indramayu',
#  u'hull',
#  u'natal/rn',
#  u'\u5343\u8449\u5e02',
#  u'city of evil',
#  u'aberdeen scotland',
#  u'here',
#  u'pluto',
#  u'bangkok',
#  u'denpasar  bali',
#  u'studio',
#  u'\u5c71\u53e3\u770c',
#  u'oman',
#  u'nomaden',
#  u'behind you ',
#  u'\u611b\u77e5\u770c\u540d\u53e4\u5c4b\u5e02',
#  u'vigo',
#  u'dominican republic',
#  u'\u4eac\u90fd\u5e02',
#  u'jakarta indonesia',
#  u'subang jaya',
#  u'indonesiajakarta',
#  u'middlesbrough',
#  u'\u30c8\u30a4\u30ec',
#  u'banjarbaru',
#  u'pontevedra',
#  u'perth wa',
#  u'bogota colombia',
#  u'cali',
#  u'indiana',
#  u'thuis',
#  u'padang',
#  u'berlin',
#  u'mg',
#  u'stamford bridge',
#  u'\u5343\u8449\u770c\u5343\u8449\u5e02',
#  u'\u795e\u5948\u5ddd\u770c\u6a2a\u6d5c\u5e02',
#  u'davao city',
#  u'mataram',
#  u'india',
#  u'cape town',
#  u'\u5b66\u5712\u90fd\u5e02',
#  u'\u043a\u0438\u0435\u0432',
#  u'santo domingo rd',
#  u'isle of wight',
#  u'uae',
#  u'haarlem',
#  u'new delhi',
#  u'yogyakarta',
#  u'\u9752\u68ee\u770c',
#  u'indianapolis in',
#  u'\u3061\u30fc\u3070\u304f\u3093',
#  u'west borneo',
#  u'saudi arabia - riyadh ',
#  u'\u672d\u5e4c\u5e02',
#  u'kuching',
#  u'denpasar bali',
#  u'under the mistletoe',
#  u'yokohama japan',
#  u'dallas tx',
#  u'jogjakarta',
#  u'seoulkorea',
#  u'london',
#  u'rio de janeiro - brasil',
#  u'kajang',
#  u'japan',
#  u'doncaster',
#  u'\u307b\u3063\u304b\u3044\u3069\u30fc',
#  u'i n d o n e s i a',
#  u'somewhere',
#  u'\u304a\u3046\u3061',
#  u'new orleans',
#  u'\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433',
#  u'wales',
#  u'belarus',
#  u'cavite philippines',
#  u'maracaibo',
#  u'\u3053\u2191\u3053\u2193',
#  u'somewhere in neverland',
#  u'saint-petersburg',
#  u'hertfordshire',
#  u'netherlands',
#  u'detroit',
#  u'las vegas nv',
#  u'\u9ad8\u77e5\u770c',
#  u'\u3057\u305a\u304a\u304b',
#  u'\u9999\u5ddd\u770c',
#  u'milan',
#  u'malacca',
#  u'thailand ',
#  u'\u3055\u3044\u305f\u307e\u5e02',
#  u'ru',
#  u'rs',
#  u'kuwait',
#  u'rd',
#  u'\u3075\u3068\u3093',
#  u'palembang indonesia',
#  u'venezuela',
#  u'rj',
#  u'arizona',
#  u'dubai ',
#  u'bogor indonesia',
#  u'barcelona spain',
#  u'\u5ca9\u624b\u770c',
#  u'auckland new zealand',
#  u'pontianakindonesia',
#  u'tasikmalaya indonesia',
#  u'gloucester',
#  u'wolverhampton',
#  u'\u611b\u5a9b',
#  u'montevideo uruguay',
#  u'cairo egypt',
#  u'elche',
#  u'strasbourg',
#  u'tokyojapan',
#  u'\u3055\u3044\u305f\u307e\u3051\u3093',
#  u'california',
#  u'bulacan',
#  u'cebu city',
#  u'hollywood',
#  u'brazil ',
#  u'\u3042\u306a\u305f\u306e\u5fc3\u306e\u4e2d',
#  u'\u7530\u820e',
#  u'toronto',
#  u'rep\xfablica dominicana',
#  u'pamplona',
#  u'londonuk',
#  u'samsun',
#  u'\uc778\ub3c4\ub124\uc2dc\uc544',
#  u'doha qatar',
#  u'bandung-indonesia',
#  u'gallifrey',
#  u'bkkthailand',
#  u'boston',
#  u'm\xfcnchen',
#  u'\u3050\u3093\u307e',
#  u'jakarta city',
#  u'paris\u2665',
#  u'perak',
#  u'san diego',
#  u'bandar lampung indonesia',
#  u'pittsburgh',
#  u'\u5948\u826f',
#  u'bintaro',
#  u'jogjakarta indonesia',
#  u'paris\u2600',
#  u'surabayaindonesia',
#  u'raleigh nc',
#  u'germany',
#  u'bradford',
#  u'\u0627\u0644\u0645\u062f\u064a\u0646\u0629 \u0627\u0644\u0645\u0646\u0648\u0631\u0629',
#  u'makati',
#  u'\u305d\u3053\u3089\u3078\u3093',
#  u'bacolod city',
#  u'\u5343\u8449\u770c\u5e02\u5ddd\u5e02',
#  u'belo horizonte - mg',
#  u'new delhi india',
#  u'earth',
#  u'den haag',
#  u'mnl ',
#  u'cartagena',
#  u'mullingarwestmeathireland',
#  u'minnesota',
#  u'\u4eac\u90fd\u5e9c',
#  u'bahrain',
#  u'\u77f3\u5ddd\u770c',
#  u'\u6c96\u7e04',
#  u'new york city',
#  u'with justin',
#  u'guatemala',
#  u'\u30d1\u30bd\u30b3\u30f3\u306e\u524d',
#  u'\u30b8\u30e7\u30a6\u30c8\u5730\u65b9',
#  u'la plata',
#  u'\u305d\u306e\u3078\u3093',
#  u'philipines',
#  u'my own world',
#  u'penang malaysia',
#  u'nottingham uk',
#  u'dubai\u2665',
#  u'paran\xe1',
#  u'brazil',
#  u'bandung indonesia',
#  u'jerez de la frontera',
#  u'essex uk',
#  u'\u57fc\u7389\u770c',
#  u'glasgow',
#  u'perth western australia',
#  u'cianjur',
#  u'adelaide australia',
#  u'united arab emirates',
#  u'manchester uk',
#  u'medan indonesia',
#  u'terengganu',
#  u'mersin',
#  u'mystic falls',
#  u'russia',
#  u'las vegas',
#  u'\uc778\ucc9c',
#  u'lagosnigeria',
#  u'china',
#  u'where the wild things are',
#  u'liverpool uk',
#  u'tilburg',
#  u'pekanbaru riau',
#  u'bengkulu indonesia',
#  u'semarangindonesia',
#  u'abuja',
#  u'kuwait city',
#  u'gold coast australia',
#  u'chile',
#  u'seoul ',
#  u'\u3059\u307f\u3063\u3053',
#  u'kentucky',
#  u'exoplanet',
#  u'\u6771\u4eac\u90fd\u6e2f\u533a',
#  u'mexico',
#  u'perth australia',
#  u'seattle',
#  u'id',
#  u'wonosobo',
#  u'kota kinabalu',
#  u'\u6c60\u888b',
#  u'tulungagung',
#  u'pontianak indonesia',
#  u'\u77f3\u5ddd\u770c\u91d1\u6ca2\u5e02',
#  u'\u306a\u3054\u3084',
#  u'\u6771\u4eac',
#  u'lagos nigeria',
#  u'jkt',
#  u'slovenia',
#  u'paradise ',
#  u'guayaquil',
#  u'paris ',
#  u'\u3068\u3046\u304d\u3087\u3046',
#  u'\uc6b0\ub9ac\uc9d1',
#  u'tangerang ',
#  u'north wales',
#  u'minas gerais',
#  u'bandungjawa barat',
#  u'rome',
#  u'bandar lampung ',
#  u'roma',
#  u'wirral',
#  u'alabama',
#  u'kepo',
#  u'thionville',
#  u'kuala lumpur  malaysia',
#  u'cumbria',
#  u'alexandria',
#  u'birmingham',
#  u'tomorrowland',
#  u'kanagawa',
#  u'belfast',
#  u'jakarta id',
#  u'istanbul turkey',
#  u'osaka japan',
#  u'disini',
#  u'natal',
#  u'\u30c8\u30fc\u30ad\u30e7\u30fc',
#  u'newcastle',
#  u'm\xe1laga',
#  u'depok jawa barat',
#  u'semarang jawa tengah',
#  u'\u304b\u306a\u304c\u308f',
#  u'#rpwithnoagency',
#  u'malaysia',
#  u'jupiter',
#  u'\u8de1\u90e8\u738b\u56fd',
#  u'lahore',
#  u'dki jakarta indonesia',
#  u's\xe3o paulo brasil',
#  u'bangalore',
#  u'nowhere but up',
#  u'\u3086\u304b\u308a\u738b\u56fd',
#  u'seoulsouth korea',
#  u'cloud 9',
#  u'\uc11c\uc6b8',
#  u'indonesia jakarta',
#  u'jacksonville fl',
#  u'somewhere i belong',
#  u'\u043e\u043c\u0441\u043a',
#  u'bath',
#  u'\u95a2\u6771',
#  u'cardiff',
#  u'amsterdam',
#  u'new jersey',
#  u'south korea',
#  u'asunci\xf3n paraguay',
#  u'leeds uk',
#  u'johannesburg south africa',
#  u'rio de janeiro',
#  u'davao city philippines',
#  u'\u611b\u77e5\u770c',
#  u'polska',
#  u'dubai uae',
#  u'ipoh perak',
#  u'plymouth',
#  u'philadelphia pa',
#  u'rio grande do sul',
#  u'nj',
#  u'depok',
#  u'south africa',
#  u'nc',
#  u'\u5c90\u961c',
#  u'east london',
#  u'ny',
#  u'san antonio',
#  u'bandung  indonesia',
#  u'\u548c\u6b4c\u5c71',
#  u'majalengka',
#  u'devon',
#  u'caxias do sul',
#  u'jeddah',
#  u'connecticut',
#  u'vietnam',
#  u'atlantaga',
#  u'somewhere in the world',
#  u'global',
#  u'melaka',
#  u'\u795e\u5948\u5ddd',
#  u'badajoz',
#  u'\u3046\u3069\u3093\u770c',
#  u'\u304a\u304a\u3055\u304b',
#  u'ksa - riyadh',
#  u'curitiba',
#  u'\u5e83\u5cf6',
#  u'egypt ',
#  u's\xe3o paulo - sp',
#  u'cairoegypt',
#  u'houston tx',
#  u'karachi pakistan',
#  u'palembang sumatera selatan',
#  u'c\xe1diz',
#  u'philippines',
#  u'alicante',
#  u'trinidad and tobago',
#  u'bahia',
#  u'kedah',
#  u'\u611b\u5a9b\u770c',
#  u'alexandriaegypt',
#  u'your mind',
#  u'birmingham england',
#  u'samarinda',
#  u'tanjungpinang',
#  u'\u5c71\u68a8',
#  u'\u77f3\u5ddd',
#  u'kyoto japan',
#  u'okinawa',
#  u'en mi casa',
#  u'dublin',
#  u'bangi',
#  u'montreal',
#  u'shah alam selangor',
#  u'durham',
#  u'in the moment',
#  u'rosewood',
#  u'\u95a2\u897f',
#  u'in your heart \u2665',
#  u'lampung',
#  u'lion city',
#  u'behind you',
#  u'athens',
#  u'france',
#  u'peru',
#  u'ksa',
#  u'\u0645\u0643\u0629 \u0627\u0644\u0645\u0643\u0631\u0645\u0629',
#  u'\u3044\u3070\u3089\u304d',
#  u'somewhere awesome',
#  u'bandung west java indonesia',
#  u'asunci\xf3n - paraguay',
#  u'paris france',
#  u'everywhere',
#  u'karawang',
#  u'\u5ddd\u5d0e',
#  u'tokyo',
#  u'kuala terengganu',
#  u'argentina ',
#  u'australia ',
#  u'pretoria',
#  u'hiroshima',
#  u'uruguay',
#  u'pekanbaru indonesia',
#  u'south borneo indonesia',
#  u'oslo',
#  u'in your heart',
#  u'straya',
#  u'vancouver',
#  u'\u3068\u30fc\u304d\u3087\u30fc',
#  u'per\xfa',
#  u'springfield',
#  u'edinburgh',
#  u'\u4e09\u91cd\u770c',
#  u'\u5343\u8449\u770c',
#  u'palembang  indonesia',
#  u'\u3053\u305f\u3064',
#  u'right here',
#  u'sp',
#  u'gresik',
#  u'gij\xf3n',
#  u'distrito 12',
#  u'sc',
#  u'bandung west java',
#  u'sa',
#  u'surabaya  indonesia',
#  u'sg',
#  u'\u5c71\u68a8\u770c',
#  u'\u540d\u53e4\u5c4b\u5e02',
#  u'\u5f69\u306e\u56fd',
#  u'northampton',
#  u'united kingdom ',
#  u'espa\xf1a',
#  u'balikpapan indonesia',
#  u'canad\xe1',
#  u'yorkshire',
#  u'united kingdom',
#  u'the world',
#  u'ipswich',
#  u'\u5317\u6d77\u9053\u672d\u5e4c\u5e02',
#  u'norway',
#  u'charlotte nc',
#  u'texas',
#  u'\u5317\u306e\u5927\u5730',
#  u'groningen',
#  u'\xfct: 0000',
#  u'deutschland',
#  u'stockholm',
#  u'oviedo',
#  u'honduras',
#  u'almer\xeda',
#  u'cairo',
#  u'selangor',
#  u'antalya',
#  u'goi\xe2nia',
#  u'canada',
#  u'jogja',
#  u'space',
#  u'yogyakarta indonesia',
#  u'trabzon',
#  u'jakarta selatan',
#  u'kent',
#  u'internet',
#  u'land of ooo',
#  u'vi\u1ec7t nam',
#  u'sheffield',
#  u'tamworth',
#  u'semarang indonesia',
#  u'riyadh - saudi arabia',
#  u'abu dhabi uae',
#  u'turkiye',
#  u'toronto canada',
#  u'bekasi',
#  u'pune',
#  u'brasil',
#  u'makassar indonesia',
#  u'221b baker street',
#  u'makati city philippines',
#  u'saudi arabia  riyadh',
#  u'belfast northern ireland',
#  u'\u0440\u043e\u0441\u0441\u0438\u044f \u043c\u043e\u0441\u043a\u0432\u0430',
#  u'romania',
#  u'toulouse',
#  u'southern california',
#  u'glasgow scotland',
#  u'santander',
#  u'bahamas',
#  u'republic of korea',
#  u'smtown',
#  u'karachi',
#  u'neverland',
#  u'moscow',
#  u'cornwall',
#  u'selangor malaysia',
#  u'thai',
#  u'\u6803\u6728',
#  u'\u6803\u6728\u770c',
#  u'earth ',
#  u'ja\xe9n',
#  u'lugo',
#  u'manado indonesia',
#  u'kuwait ',
#  u'uk ',
#  u'the netherlands',
#  u'portsmouth',
#  u'saitama',
#  u'pekanbaru',
#  u'preston',
#  u'worcester',
#  u'korea selatan',
#  u'saudi arabia-riyadh',
#  u'\u5c71\u5f62\u770c',
#  u'zombieland',
#  u'houston texas',
#  u'makkah',
#  u'here there everywhere',
#  u'santiago',
#  u'scotland ',
#  u'cordoba',
#  u'semarang',
#  u'banda aceh indonesia',
#  u'bekasi indonesia',
#  u'america',
#  u'chicago il',
#  u'pontianak kalimantan barat',
#  u'riyadh ',
#  u'rio de janeiro ',
#  u'jakarta',
#  u'en mi mundo',
#  u'leicester',
#  u' indonesia',
#  u'central java indonesia',
#  u'baltimore md',
#  u'follows you',
#  u'wonderland ',
#  u'malaysia ',
#  u'porto alegre - rs',
#  u'mumbai india',
#  u'\u5317\u6d77\u9053',
#  u'mexico df',
#  u'curitiba - pr',
#  u'\u798f\u5ca1\u770c\u798f\u5ca1\u5e02',
#  u'seremban',
#  u'cardiff wales',
#  u'\u6771\u4eac\u90fd\u4e2d\u91ce\u533a',
#  u'tenerife',
#  u'cheshire',
#  u'recife',
#  u'bulgaria',
#  u'makassar ',
#  u'tangerangindonesia',
#  u'\u4e8c\u6b21\u5143',
#  u'bursa',
#  u'\u798f\u5cf6',
#  u'palembangindonesia',
#  u'guayaquil ecuador',
#  u'kuching sarawak',
#  u'\u8328\u57ce\u770c',
#  u'reading',
#  u'pekanbaru riau indonesia',
#  u'jakarta-indonesia',
#  u'osakajapan',
#  u'riyadh saudi arabia',
#  u'on earth',
#  u'pakistan',
#  u'red ocean',
#  u'dki jakarta',
#  u'\u5c90\u961c\u770c',
#  u'lahore pakistan',
#  u'sao paulo',
#  u'\u8aa0\u51db\u9ad8\u6821',
#  u'turkey',
#  u'\u8a66\u3055\u308c\u308b\u5927\u5730',
#  u'atlanta ga',
#  u'\u3055\u3044\u305f\u307e',
#  u'cirebon',
#  u'purwakarta',
#  u'mars',
#  u'madrid ',
#  u'pasig city',
#  u'25\u6b21\u5143',
#  u'kuwait \u2665',
#  u'viet nam',
#  u'bekasi ',
#  u'south carolina',
#  u'emirates stadium',
#  u'sevilla ',
#  u'yk',
#  u'kenya',
#  u'istanbulturkey',
#  u'quezon city philippines',
#  u'guadalajara',
#  u'manila',
#  u'middle of nowhere',
#  u'bacolod city philippines',
#  u'klang',
#  u'singapore',
#  u'daerah istimewa yogyakarta',
#  u'tangerang indonesia',
#  u'\u5ca1\u5c71',
#  u'granada',
#  u'\u043f\u043e\u043b\u044c\u0448\u0430',
#  u'pennsylvania',
#  u'\u3042\u3044\u3061\u3051\u3093',
#  u'ireland ',
#  u'\u79cb\u7530\u770c',
#  u'cheltenham',
#  u'\u6771\u4eac\u90fd',
#  u'brisbane',
#  u'new york new york',
#  u'bali indonesia',
#  u'barbados',
#  u'\u79c0\u5fb3\u9ad8\u6821',
#  u'next to you',
#  u'santiago chile',
#  u'perth',
#  u'\u672d\u5e4c',
#  u'saudi arabia riyadh',
#  u'\u795e\u5948\u5ddd\u770c',
#  u'delhi',
#  u'kediri',
#  u'virginia',
#  u'world',
#  u'medellin',
#  u'rome italy',
#  u'\u611b\u77e5',
#  u'jakarta timur',
#  u'medanindonesia',
#  u'madrid',
#  u'lebanon',
#  u'abidjan',
#  u'london ',
#  u'wigan',
#  u'madriz',
#  u'\u3042\u306a\u305f\u306e\u5f8c\u308d',
#  u'candyfornia',
#  u'gorontalo',
#  u'shah alam',
#  u'los angeles ',
#  u'pittsburgh pa',
#  u'austin tx',
#  u'\u65b0\u5bbf',
#  u'moon',
#  u'cavite',
#  u'forks',
#  u'republic of the philippines',
#  u'florian\xf3polis',
#  u'onder je bed',
#  u'kyoto',
#  u'\u516b\u738b\u5b50',
#  u'+965',
#  u'\u30b5\u30a4\u30ec\u30f3\u30c8\u30d2\u30eb',
#  u'\u4e8c\u6b21\u5143\u3068\u4e09\u6b21\u5143\u306e\u72ed\u9593',
#  u'thailand',
#  u'in your head',
#  u'edinburgh scotland',
#  u'brighton',
#  u'\u3042\u3044\u3061',
#  u'western australia',
#  u'kingdom of saudi arabia',
#  u'my world',
#  u'austin texas',
#  u'barnsley',
#  u'albacete',
#  u'cambridge',
#  u'essex',
#  u'united states',
#  u'\u4e09\u91cd',
#  u'philadelphia',
#  u'somewhere only we know',
#  u'italia',
#  u'valencia',
#  u'\u6771\u4eac\u90fd\u8db3\u7acb\u533a',
#  u'\u6771\u4eac\u90fd\u6e0b\u8c37\u533a',
#  u'jakarta barat',
#  u'warrington',
#  u'madrid spain',
#  u'\u6ecb\u8cc0',
#  u's\xe3o paulo - brasil',
#  u'\u6771\u4eac\u90fd\u7df4\u99ac\u533a',
#  u's\xe3o paulo sp',
#  u'\u3055\u3063\u307d\u308d',
#  u'ad',
#  u'\u3061\u3070',
#  u'yokohama',
#  u'\u6771\u4eac\u90fd\u5927\u7530\u533a',
#  u'istanbul',
#  u'bogot\xe1 colombia',
#  u'everywhere!',
#  u'everywhere ',
#  u'\u5922\u306e\u4e2d',
#  u'in the middle of nowhere',
#  u'bandarlampung',
#  u'bumi allah',
#  u'massachusetts',
#  u'bangkok  thailand',
#  u'di hatimu',
#  u'\u3075\u304f\u304a\u304b',
#  u'london united kingdom',
#  u'barcelona',
#  u'\u4ed9\u53f0\u5e02',
#  u'\u57fc\u7389\u770c\u5ddd\u53e3\u5e02',
#  u'bolton',
#  u'seoul south korea',
#  u'indonesia raya',
#  u'my house',
#  u'mnl',
#  u'bekasi timur',
#  u'milky way',
#  u'pc\u306e\u524d',
#  u'adana',
#  u'huddersfield',
#  u'ghana',
#  u'ksa ',
#  u'minas gerais ',
#  u'indonesia\u2665',
#  u'johor bahru',
#  u'lima peru',
#  u'brooklyn ny',
#  u'heaven',
#  u'norfolk',
#  u'serang indonesia',
#  u'somewhere ',
#  u'bogorindonesia',
#  u'\u5bae\u57ce\u770c',
#  u'\u81ea\u5ba4',
#  u'south east london',
#  u'\u0645\u0635\u0631',
#  u'\u6a2a\u6d5c',
#  u'\u5fb3\u5cf6',
#  u'\u5927\u5206',
#  u'medan sumatera utara',
#  u'\u81ea\u5b85',
#  u'zaragoza',
#  u'stoke-on-trent',
#  u'\u0627\u0644\u0642\u0635\u064a\u0645',
#  u'shah alam malaysia',
#  u'another world',
#  u'leeds',
#  u'lima per\xfa',
#  u'iraq',
#  u'padangindonesia',
#  u'sapphire blue ocean',
#  u'minsk',
#  u'paradise city',
#  u'miami beach',
#  u'lagos',
#  u'san francisco ca',
#  u'\u304a\u30fc\u3055\u304b',
#  u'new zealand',
#  u'42 wallaby way sydney',
#  u'israel',
#  u'makassar sulawesi selatan',
#  u'natal - rn',
#  u'dublin ireland',
#  u'bedford',
#  u'bulacan philippines',
#  u'cebu city philippines',
#  u'salvador',
#  u'\u3053\u3053',
#  u'los angeles california',
#  u'\u5e83\u5cf6\u770c',
#  u'hong kong',
#  u'valencia espa\xf1a',
#  u'\u79cb\u7530',
#  u'quezon city',
#  u'johannesburg',
#  u'republica dominicana',
#  u'malang',
#  u'goat',
#  u'cirebon indonesia',
#  u'mystic falls ',
#  u'seoul',
#  u'\u5343\u8449\u770c\u67cf\u5e02',
#  u'ciudad real',
#  u'jakartaindonesia',
#  u'bkk',
#  u'\u305d\u306e\u8fba',
#  u'jakarta utara',
#  u'palma de mallorca',
#  u'eindhoven',
#  u'bogor',
#  u'\u5948\u826f\u770c',
#  u'joho',
#  u't\xfcrkiye ',
#  u'maracaibo venezuela',
#  u'world wide',
#  u'putrajaya',
#  u'ampang',
#  u'\u5175\u5eab\u770c',
#  u'hell',
#  u'sapporo',
#  u'kudus',
#  u'saitama japan',
#  u'bristol england',
#  u'argentina',
#  u'south florida',
#  u'blitar',
#  u'salamanca',
#  u'\u798f\u5ca1',
#  u'\u5175\u5eab\u770c\u795e\u6238\u5e02',
#  u'oxford',
#  u'rack city',
#  u'in your heart ',
#  u'\u9577\u91ce',
#  u'\u3072\u308d\u3057\u307e',
#  u'newcastle upon tyne',
#  u'jekardah',
#  u'england',
#  u'osaka',
#  u'all around the world',
#  u'batu pahat',
#  u'\u795e\u6238',
#  u'gotham city',
#  u'abha',
#  u'nairobi kenya',
#  u'\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433',
#  u'valencia venezuela',
#  u'paradise',
#  u'asgard',
#  u'catalunya',
#  u'wisconsin',
#  u'damansara',
#  u'norwich',
#  u'timeline',
#  u'abudhabi',
#  u'west midlands',
#  u'disneyland',
#  u'finland',
#  u'bilbao',
#  u'syria',
#  u'your timeline',
#  u'kuantan',
#  u'\u304a\u5e03\u56e3\u306e\u4e2d',
#  u'hyderabad',
#  u'honeymoon ave',
#  u'london uk',
#  u'athens greece',
#  u'colombia',
#  u'kobe',
#  u'in the world',
#  u'saudi arabia ',
#  u'\u304a\u3075\u3068\u3093',
#  u'makassar',
#  u'aichi',
#  u'rio de janeiro brasil',
#  u'madiun',
#  u'washington dc',
#  u'nigeria',
#  u'ecuador',
#  u'khobar',
#  u'puchong',
#  u'philippines ',
#  u'\u5343\u8449\u770c\u8239\u6a4b\u5e02',
#  u'jordan',
#  u'jambi',
#  u'\u6771\u4eac\u90fd\u4e16\u7530\u8c37\u533a',
#  u'\u30ab\u30f3\u30c8\u30fc',
#  u'over the rainbow',
#  u'garut',
#  u'\u57fc\u7389',
#  u'\u5bae\u5d0e\u770c',
#  u'bandung ',
#  u'\uc77c\ubcf8',
#  u'philly',
#  u'bras\xedlia',
#  u'abu dhabi',
#  u'scotland',
#  u'south borneo',
#  u'd[m]v',
#  u'japan tokyo',
#  u's\xe3o paulo',
#  u'brooklyn',
#  u'\u5927\u5206\u770c',
#  u'southampton',
#  u'manila philippines',
#  u'cincinnati ohio',
#  u'bandung - indonesia',
#  u'kl',
#  u'chester',
#  u'galicia',
#  u'surrey',
#  u'santiago bernabeu',
#  u'\u5bcc\u5c71',
#  u'surabaya',
#  u'neverland ',
#  u'chiba japan',
#  u'rotterdam',
#  u'\u7fa4\u99ac',
#  u'\u5bae\u57ce',
#  u'heaven ',
#  u'south wales',
#  u'international',
#  u'mnl philippines',
#  u'\u043c\u0438\u043d\u0441\u043a',
#  u'\u95a2\u6771\u5730\u65b9',
#  u'luton',
#  u'\ub300\uad6c',
#  u'\u4fee\u7f85\u306e\u56fd',
#  u'croatia',
#  u'switzerland',
#  u'jepara',
#  u'jember',
#  u'yogyakartaindonesia',
#  u'pontianak',
#  u'+62',
#  u'jeddah \u2665',
#  u'lisbon',
#  u'outer space',
#  u'cibubur',
#  u'aberdeen',
#  u'\u5927\u962a',
#  u'toronto ontario',
#  u'\u9759\u5ca1\u770c',
#  u'toledo',
#  u'swansea',
#  u'europe',
#  u'solo',
#  u'dammam',
#  u'karanganyar',
#  u'nashville',
#  u'\u043d\u043e\u0432\u043e\u0441\u0438\u0431\u0438\u0440\u0441\u043a',
#  u'\ub300\ud55c\ubbfc\uad6d',
#  u'moscow russia',
#  u'poland ',
#  u'buenos aires argentina',
#  u'caracas-venezuela',
#  u't\xfcrkiye',
#  u'baltimore',
#  u'czech republic',
#  u'exo planet',
#  u'tennessee',
#  u'almeria',
#  u'swindon',
#  u'ergens',
#  u'buenos aires',
#  u'\u718a\u672c',
#  u'\u4f50\u8cc0',
#  u'mnl ph',
#  u'ireland',
#  u'ph',
#  u'\u0443\u043a\u0440\u0430\u0438\u043d\u0430',
#  u'\u306b\u3063\u307d\u3093',
#  u'johor',
#  u'istanbul/turkey',
#  u't\xfcrkiye/istanbul',
#  u'santa catarina',
#  u'canada ',
#  u'barranquilla',
#  u'liverpool england',
#  u'bengkulu',
#  u'coventry',
#  u'here there and everywhere',
#  u'louisville ky',
#  u'\u9ad8\u77e5',
#  u'banjarmasin',
#  u'mordor',
#  u'portugal',
#  u'jpn',
#  u'sidoarjo',
#  u'espa\xf1a ',
#  u'rio',
#  u'\u9752\u68ee',
#  u'eski\u015fehir',
#  u'italy',
#  u'fukuoka japan',
#  u'caloocan city',
#  u'dunia',
#  u'indianapolis',
#  u'dihatimu',
#  u'bkk thailand',
#  u'costa rica',
#  u'\u307b\u3063\u304b\u3044\u3069\u3046',
#  u'ipohperak',
#  u'nantes',
#  u'\u9759\u5ca1\u770c\u6d5c\u677e\u5e02',
#  u'el salvador',
#  u'poland',
#  u'malang indonesia',
#  u'birmingham ',
#  u'boulevard of broken dreams',
#  u'enschede',
#  u'\u3068\u3061\u304e',
#  u'indonesia ',
#  u'ldn',
#  u'bandar lampung',
#  u'caracas - venezuela',
#  u'taiwan',
#  u'\u30b0\u30f3\u30de\u30fc',
#  u'riyadh  saudi arabia',
#  u'stockholm sweden',
#  u'loading',
#  u'\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0647',
#  u'bandar baru bangi',
#  u'sydney',
#  u'kuchingsarawak',
#  u'indonesian',
#  u'australia',
#  u'\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0629',
#  u'cambridge uk',
#  u'dubai',
#  u'all around the world ',
#  u'new york ',
#  u'\u6e58\u5357',
#  u'endless road 7058',
#  u'saudi arabia - jeddah',
#  u'sakarya',
#  u'ciamis',
#  u'nairobi',
#  u'\u3069\u3063\u304b',
#  u'palu',
#  u'wonderland',
#  u'jakarta  indonesia',
#  u'richmond va',
#  u'qatar',
#  u'istanbul ',
#  u'surakarta',
#  u'\u0440\u043e\u0441\u0441\u0438\u044f',
#  u'mnl phl',
#  u'\u304a\u5e03\u56e3',
#  u'bandung jawa barat',
#  u'bh',
#  u'nowhere',
#  u'\u5317\u56fd',
#  u'cimahi',
#  u'blackburn',
#  u'\u798f\u5ca1\u770c',
#  u'north london',
#  u'melbourne',
#  u'idk',
#  u'pampanga philippines',
#  u'\u5ca1\u5c71\u770c',
#  u'the moon',
#  u'denpasarbali',
#  u'\u718a\u672c\u770c',
#  u'melbourne australia',
#  u'izmir ',
#  u'west london',
#  u'bikinibroek',
#  u'oslo norway',
#  u'alriyadh',
#  u'porto alegre',
#  u'c\xf3rdoba',
#  u'\u5922\u306e\u56fd',
#  u'\u0627\u0644\u062e\u0628\u0631',
#  u'us',
#  u'\u6771\u4eac\u90fd\u516b\u738b\u5b50\u5e02',
#  u'morocco',
#  u'uk',
#  u'marseille',
#  u'south london',
#  u'banda aceh',
#  u'batangas philippines',
#  u'london town',
#  u'\u5927\u962a\u5e9c\u5927\u962a\u5e02',
#  u'france ',
#  u'\u65b0\u6f5f\u770c',
#  u'caracas',
#  u'peterborough',
#  u'kuwait\u2665',
#  u'tangerang selatan',
#  u'dakar',
#  u'san diego ca',
#  u'nice',
#  u'jambi indonesia',
#  u'makassarindonesia',
#  u'\u3060\u3055\u3044\u305f\u307e',
#  u'pekanbaruriau',
#  u'santiago de compostela',
#  u'los angeles ca',
#  u'shinee world',
#  u'maldives',
#  u'bandung',
#  u'manchester ',
#  u'\u9e7f\u5150\u5cf6',
#  u'huelva',
#  u'\u6771\u5317',
#  u'bogot\xe1',
#  u'\u675c\u306e\u90fd',
#  u'amersfoort',
#  u'miami florida',
#  u'jeddah saudi arabia',
#  u'lille',
#  u'\u6771\u4eac\u90fd\u6c5f\u6238\u5ddd\u533a',
#  u'nashville tn',
#  u'\ubd80\uc0b0',
#  u'penang',
#  u'maryland',
#  u'konoha',
#  u'ankara',
#  u'\u6e0b\u8c37',
#  u'miami fl',
#  u'fukuoka',
#  u'palembang city',
#  u'\u798f\u4e95\u770c',
#  u'bournemouth',
#  u'\u65e5\u672c\u56fd',
#  u'leicestershire',
#  u'tokyo ',
#  u'camp half-blood',
#  u'riyadh',
#  u'bogota',
#  u'g\xf6teborg',
#  u'hungary',
#  u'bikini bottom',
#  u'chicago',
#  u'kobe japan',
#  u'in your dreams',
#  u'\u798f\u5cf6\u770c',
#  u'\u7d05\u9b54\u9928',
#  u'depokindonesia',
#  u'singapore ',
#  u'newyork',
#  u'\u304a\u304b\u3084\u307e',
#  u'\u2665 ',
#  u'jakarta indonesia ',
#  u'ukraine',
#  u'under your bed',
#  u'lampung indonesia',
#  u'kocaeli',
#  u'cape town south africa',
#  u'\u6771\u4eac\u90fd\u65b0\u5bbf\u533a',
#  u'denpasar bali indonesia',
#  u'derby',
#  u'bruxelles',
#  u'camp nou',
#  u'bogor jawa barat',
#  u'montpellier',
#  u'egypt',
#  u'mar del plata',
#  u'londres',
#  u'austria',
#  u'nijmegen',
#  u'san francisco',
#  u'saudi arabia',
#  u'usa',
#  u'johor bahru malaysia',
#  u'nagoya',
#  u'kuala lumpurmalaysia',
#  u'jakarta pusat',
#  u'somewhere over the rainbow',
#  u'\u5b87\u5b99',
#  u'zamora',
#  u'manilaphilippines',
#  u'islamabad',
#  u'brunei darussalam',
#  u'kelantan',
#  u'anywhere',
#  u'rio de janeiro brazil',
#  u'birmingham uk',
#  u'planet earth',
#  u'\u0627\u0644\u0643\u0648\u064a\u062a ',
#  u'\u0441\u0430\u043c\u0430\u0440\u0430',
#  u'\u043c\u043e\u0441\u043a\u0432\u0430',
#  u'narnia ',
#  u'torino',
#  u'kuala lumpur',
#  u'\u9b54\u754c',
#  u'kolkata',
#  u'\u4ed9\u53f0',
#  u'\u0441\u0430\u0440\u0430\u0442\u043e\u0432',
#  u'\u6771\u4eac\u90fd\u8c4a\u5cf6\u533a',
#  u'@alljyprp',
#  u'manaus',
#  u'nagoya japan',
#  u'surabaya indonesia',
#  u'1derland',
#  u'batam',
#  u'iloilo city philippines',
#  u'ibiza',
#  u'sendai',
#  u'm\xe9xico',
#  u's\xe3o paulo brazil',
#  u'cebu philippines',
#  u'\u4eac\u90fd',
#  u'houston',
#  u'beside you',
#  u'salatiga',
#  u'palembang ',
#  u'\u5e03\u56e3\u306e\u4e2d',
#  u'galaxy',
#  u'\u795e\u5948\u5ddd\u770c\u5ddd\u5d0e\u5e02',
#  u'la',
#  u'fortaleza',
#  u'puerto rico',
#  u'kota damansara',
#  u'\u0627\u0644\u0631\u064a\u0627\u0636 ',
#  u'\u5343\u8449',
#  u'manadoindonesia',
#  u'bandung jawa barat indonesia',
#  u'\u65b0\u6f5f',
#  u'nyc',
#  u'\u795e\u6238\u5e02',
#  u'not found',
#  u'jambi city',
#  u'latvia',
#  u'nairobikenya',
#  u'district 12',
#  u'\u540d\u53e4\u5c4b',
#  u'belgrade',
#  u'metz',
#  u'sydney australia',
#  u'melaka malaysia',
#  u'serbia',
#  u'bumi',
#  u'asturias',
#  u'santiago de chile',
#  u'\u3069\u3053\u304b',
#  u'pampanga',
#  u'russia moscow',
#  u'\u5bae\u57ce\u770c\u4ed9\u53f0\u5e02',
#  u'\u5175\u5eab',
#  u'cwb',
#  u'\u96ea\u56fd',
#  u'durban',
#  u'milton keynes',
#  u'brisbane australia',
#  u'hogwarts',
#  u'belgique',
#  u'surabaya ',
#  u'makati philippines',
#  u'in heaven',
#  u'napoli',
#  u'cadiz',
#  u'florida',
#  u'believe tour',
#  u'beirut lebanon',
#  u'orlando florida',
#  u'lyon france',
#  u'jakarta - indonesia',
#  u'\u57fc\u7389\u770c\u3055\u3044\u305f\u307e\u5e02',
#  u'tokyo japan',
#  u'\u305d\u3053',
#  u'columbus ohio',
#  u'unknown',
#  u'north carolina',
#  u'new york',
#  u'recife - pe',
#  u'belo horizonte',
#  u'\u611b\u5a9b\u770c\u677e\u5c71\u5e02',
#  u'hyogo',
#  u'\u306b\u3044\u304c\u305f',
#  u'detroit mi',
#  u'sheffield uk',
#  u'bristol uk',
#  u'marbella',
#  u'jakarta ',
#  u'under the sea',
#  u'holland',
#  u'euskal herria',
#  u'bed',
#  u'sweden',
#  u'bekasiindonesia',
#  u'kuala lumpur ',
#  u'\u062c\u062f\u0647',
#  u'storybrooke',
#  u'london england',
#  u'sevilla',
#  u'klaten',
#  u'old trafford',
#  u'\u0645\u0643\u0647 \u0627\u0644\u0645\u0643\u0631\u0645\u0647',
#  u'\u3064\u304f\u3070',
#  u'home sweet home',
#  u'dallas',
#  u'chiba',
#  u'\u30ab\u30f3\u30c8\u30fc\u5730\u65b9',
#  u'worldwide',
#  u'manila ph',
#  u'nancy',
#  u'\u7fa4\u99ac\u770c',
#  u'bangkokthailand',
#  u'medan',
#  u'\u304a\u82b1\u7551',
#  u'dreamland',
#  u'amman jordan',
#  u'\u062c\u062f\u0629',
#  u'milano',
#  u'saudi arabia - riyadh',
#  u'riyadhsaudi arabia',
#  u'cairo  egypt',
#  u'los angeles',
#  u'bordeaux',
#  u'tampa fl',
#  u'manchester',
#  u'\u0627\u0644\u0631\u064a\u0627\u0636',
#  u'in your mind',
#  u'recife-pe',
#  u'mumbai',
#  u'phillipines',
#  u'q8',
#  u'parisfrance',
#  u'bangkok thailand',
#  u'serang',
#  u'michigan',
#  u'magelang',
#  u'kuantan pahang',
#  u'\u9759\u5ca1',
#  u'denmark',
#  u'\u5bcc\u5c71\u770c',
#  u'ohio',
#  u'lisboa',
#  u'okayama',
#  u'korea',
#  u'greece',
#  u'le\xf3n',
#  u'\u0440\u043e\u0441\u0442\u043e\u0432-\u043d\u0430-\u0434\u043e\u043d\u0443',
#  u'\u4f50\u8cc0\u770c',
#  u'lyon',
#  u'balikpapan',
#  u'dundee',
#  u'bandungindonesia',
#  u'purwokerto',
#  u'bedfordshire',
#  u'england uk',
#  u'\u6771\u4eac\u90fd\u6749\u4e26\u533a',
#  u'on your mind',
#  u'pretoria south africa',
#  u'west java',
#  u'colombia ',
#  u'jeddah ksa',
#  u'bristol',
#  u'jersey',
#  u'\u5927\u962a\u5e9c',
#  u'sukabumi',
#  u'a coru\xf1a',
#  u'la la land',
#  u'\u90fd\u5185',
#  u'new york ny',
#  u'santo domingo',
#  u'boston ma',
#  u'louisiana',
#  u'cilegon',
#  u'\u65e5\u672c',
#  u'liverpool',
#  u'mi casa',
#  u'hamburg',
#  u'atlanta',
#  u'\u6c96\u7e04\u770c',
#  u'spain',
#  u'brasilia',
#  u'apeldoorn',
#  u's\xe3o paulo ',
#  u'madrid espa\xf1a',
#  u'jawa barat',
#  u'your heart',
#  u'hogwarts ',
#  u'bacoor cavite',
#  u'va',
#  u'\u5730\u7403',
#  u'solo indonesia',
#  u'\u5927\u962a\u5e02',
#  u'\u3058\u3083\u3071\u3093',
#  u'jeddah ',
#  u'underground',
#  u'batam indonesia',
#  u'bali',
#  u'phl',
#  u'far far away',
#  u'anfield',
#  u'\u6771\u4eac\u90fd\u677f\u6a4b\u533a',
#  u'malaga',
#  u'indonesia',
#  u'\u5ca9\u624b',
#  u'utrecht',
#  u'denpasar',
#  u'malang jawa timur',
#  u'niigata',
#  u'burgos',
#  u'overal en nergens',
#  u'blackpool',
#  u'cork ireland',
#  u'medansumatera utara',
#  u'izmir',
#  u'around the world',
#  u'hatimu',
#  u'valladolid',
#  u'belgium',
#  u'atlanta georgia',
#  u'cuenca',
#  u'\u2514a',
#  u'england ',
#  u'lincoln',
#  u'\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e44\u0e17\u0e22',
#  u'lost',
#  u'miami',
#  u'liverpool ',
#  u'accra',
#  u'404 not found',
#  u'\u5bae\u5d0e',
#  u'twitter',
#  u'hail',
#  u'sunderland',
#  u'manchester england',
#  u'home',
#  u'halifax',
#  u'klang selangor',
#  u'tangerang',
#  u'palencia',
#  u'\u9577\u5d0e',
#  u'seattle wa',
#  u'lasgidi',
#  u'banjarmasin indonesia',
#  u'kanagawa japan',
#  u'\u6674\u308c\u306e\u56fd',
#  u'qassim',
#  u'panem',
#  u'surakarta indonesia',
#  u'universe',
#  u'caracas venezuela',
#  u'iphone: 00000000000000',
#  u'\u306b\u307b\u3093',
#  u'pekanbaruindonesia',
#  u'rain city',
#  u'\u4e5d\u5dde',
#  u'\u9577\u91ce\u770c',
#  u'kuala lumpur malaysia',
#  u'stratford',
#  u'paris \u2665',
#  u'petaling jaya',
#  u'\u79cb\u8449\u539f',
#  u'in the clouds',
#  u'bieberland',
#  u'essex ',
#  u'sevilla espa\xf1a',
#  u'nederland',
#  u'brasil ',
#  u'c\xe1ceres',
#  u'batangas city',
#  u'\u6ecb\u8cc0\u770c',
#  u'\u5c71\u5f62',
#  u'venezuela ',
#  u'dmv',
#  u'istanbul t\xfcrkiye',
#  u'seoul korea selatan',
#  u'narnia',
#  u'\u0627\u0644\u0643\u0648\u064a\u062a',
#  u'paraguay',
#  u'ina',
#  u'riau',
#  u'illinois',
#  u'\u0627\u0644\u0645\u0645\u0644\u0643\u0629 \u0627\u0644\u0639\u0631\u0628\u064a\u0629 \u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0629',
#  u'samarinda indonesia',
#  u'padang indonesia',
#  u'west yorkshire',
#  u'palembang',
#  u'm\xe9xico df',
#  u'\u798f\u5ca1\u5e02',
#  u'orlando fl',
#  u'makati city',
#  u'mojokerto',
#  u'kota bharu']

# %%
data = get_city_timelines(locs,locs)
#data['new york'].keys()
#data['new york'][dateutil.parser.parse('2012-11-7 04:0:0')]

gen_hist_city_dicts(data)
# Out:
# procesing data for: new york
# procesing data for: london
# procesing data for: jakarta
# procesing data for: washington dc
# procesing data for: delhi
# procesing: washington dc
# procesing: jakarta
# procesing: delhi
# procesing: new york
# procesing: london

# %%
N = 10
data = numpy.random.random((N, 4))
labels = ['washington dc','boston ','atlanta ','boston','chicago ','new york','chicago','los angeles','toronto','london','rio','paris','mexico city','lima','singapore','tokyo','buenos aires','jakarta','bandung']
perchange = [765.2954809,463.7372525,397.7258134,386.8242589,330.2292783,327.3427324,304.5505823,256.7990932,215.0488599,193.8164376,114.497003,102.2998772,77.72511848,75.21486773,43.74490341,29.34335555,18.95444141,-15.96937434,-22.0135143]
abschange = [5283.6,3092.2,4955.133333,5323.733333,5463.533333,17088.6,12238.46667,9213.266667,6602,2990.2,2941.733333,1221.733333,502.9333333,898.4666667,1037.133333,551.7333333,342.2666667,-1092.933333,-710.2]
average = [690.4,666.8,1245.866667,1376.266667,1654.466667,5220.4,4018.533333,3587.733333,3070,1542.8,2569.266667,1194.266667,647.0666667,1194.533333,2370.866667,1880.266667,1805.733333,6843.933333,3226.2]

#std_dev = [132.0897675,246.9660885,280.1129455,389.5621246,769.7647952,898.7573545,404.0253237,428.7323952,221.1226507,479.8908857,296.742642,132.8113784,163.4086357,68.04985101,121.1756118,226.0939235,1584.530823,683.6933231]

# set figure size
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5,10.5)

colors =  [(random.random(),random.random(),random.random()) for i in xrange(21)]
#new_map = matplotlib.colors.LinearSegmentedColormap.from_list('new_map', colors, N=256)

subplots_adjust(bottom = 0.1)
scatter(
    perchange, abschange, c= colors, marker = 'o', s = (average/ numpy.max(average))*3000,
    cmap = get_cmap('Spectral'))
xlabel('Percentage Change in the number of tweets')
ylabel('Absolute Change in the number of tweets')
for label, x, y in zip(labels, perchange, abschange):
    annotate(
        label, 
        xy = (x, y), xytext = (-20, 20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.3),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

show()

# %%
colors = [(1,1,1)] + [(random.random(),random.random(),random.random()) for i in xrange(19)]
colors
# Out:
# [(1, 1, 1),
#  (0.3976012796500793, 0.5851930568732219, 0.531302240358008),
#  (0.6476593995518352, 0.3170077958154839, 0.6893326815506527),
#  (0.7734781895789351, 0.30227743000457175, 0.8343314951232886),
#  (0.15463864817411643, 0.38075118911778905, 0.08297460055071126),
#  (0.6363448331497698, 0.1534259169470319, 0.7140366387288206),
#  (0.30758994300199294, 0.04236013821591378, 0.9465628455064438),
#  (0.5797327562371444, 0.16589595706422533, 0.5491236610111132),
#  (0.2302271607303482, 0.8862813315523451, 0.18138784981089895),
#  (0.8797177994464053, 0.7592690995231202, 0.6960001667944247),
#  (0.9072290743667181, 0.6614375223951856, 0.9910616695051773),
#  (0.6304144316196066, 0.1976902209108382, 0.6493411166941896),
#  (0.7985151353177453, 0.05408824048497762, 0.7807805234135495),
#  (0.8183750663774159, 0.8686370197298074, 0.8619312118192668),
#  (0.22432669409769745, 0.5518450684930927, 0.4761665629686891),
#  (0.8068197726404734, 0.5996798278478322, 0.5104641724347209),
#  (0.5847946335327979, 0.934404241603464, 0.611045910764979),
#  (0.17954095116754465, 0.9582607682188665, 0.231465402094984),
#  (0.7537490233893464, 0.7776240663915683, 0.49750731943025417),
#  (0.6799413468206246, 0.6044498973711062, 0.9881546436325772)]

# %%
def write_items_to_file(items, selfpath):
    writer = csv.writer(open(selfpath, 'wb'))
    new_items = [(a.encode('utf-8'),b,c,d,e) for a,b,c,d,e in items]
    for item in new_items:
        writer.writerow(item)
        
### generate the final output for each loc
items =[]
time_in = parse('2012-11-7 4:0:0')
items.append(('location', 'per change', 'abs change','avg', 'standard dev'))
for loc in locs_dict:
    abs_change,per_change,avg,std = get_per_change(time_in,locs_dict[loc])
    t = (loc, per_change, abs_change,avg, std)
    items.append(t)


write_items_to_file(items, "../DataMining/GardenHose/final_outputs/stats/locs.csv")
